# %% [markdown]
# ### Implement Perceptron learning
#
# In this assignment, you are asked to implement perceptron learning to sove the linear classification problem.
# You may use NumPy to program your solution. Aside from that library, no other outside non-standard libraries can be used.
#
# ### Submission
#
# Once finish, convert this file to pdf, then submit  both jupyter file +pdf to canvas.
#
# ### Through your code, answer the following questions
#
# 1) what are the weights after the first epoch (based on all 5 data points)?
# 2) change the epoch to 100, is the data linear separable?
# 3) change the learning rate to 0.05, still linear seprable?

# %% [markdown]
# ![Picture1.png](attachment:Picture1.png)

# %%
import numpy as np
X_train=np.array([[1, 1], [3, 2], [2,4], [3, 4], [2,3]])
y_train=np.array([0,1,1,1,0])

# %%
################ finish the functions below

# %%
def perceptron(X, y, init_weights,lr, epochs):
    
    return updated_weights

# %%
def prediction(X,weights):
    
    return y_predicted

# %%
#Set the initial weights as -1,0 ,0 
init_weights = np.array([-1,0,0])
init_weights
# Out:
# array([-1,  0,  0])

# %%
### verify the results on the lecture, learning rate=1, epoch=1, 
#you will see after the first epoch, 3 samples are corrected classified
updated_weights=perceptron(X_train, y_train, init_weights, lr=1, epochs=1)
y_predicted=prediction(X_train,weights)

# %%
### check the accuracy on the training data
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print('Accuracy score: {}'.format(accuracy_score(y_train, y_predicted)))
